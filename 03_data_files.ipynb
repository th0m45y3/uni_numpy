# %% [markdown]
# # Форматы данных (1)

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 4: Форматы данных"
# * https://docs.python.org/3/library/json.html
# * https://docs.python.org/3/library/pickle.html
# * https://www.crummy.com/software/BeautifulSoup/bs4/doc.ru/bs4ru.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Вывести все адреса электронной почты, содержащиеся в адресной книге `addres-book.json`

# %%
import json

with open("data/addres-book.json", 'r', encoding='utf8') as f:
    js = json.load(f)

[acc['email'] for acc in js]
# Out:
# ['faina@mail.ru', 'robert@mail.ru', 'faina@mail.ru', 'robert@mail.ru']

# %% [markdown]
# 2. Вывести телефоны, содержащиеся в адресной книге `addres-book.json`

# %%
[acc['phones'] for acc in js]
# Out:
# [[{'phone': '232-19-55'}, {'phone': '+7 (916) 232-19-55'}],
#  [{'phone': '111-19-55'}, {'phone': '+7 (916) 445-19-55'}],
#  [{'phone': '232-19-55'}, {'phone': '+7 (916) 232-19-55'}],
#  [{'phone': '111-19-55'}, {'phone': '+7 (916) 445-19-55'}]]

# %% [markdown]
# 3. По данным из файла `addres-book-q.xml` сформировать список словарей с телефонами каждого из людей.

# %%
from bs4 import BeautifulSoup

with open("data/addres-book-q.xml", 'r') as f:
    xml = BeautifulSoup(f, "xml")

[ {adr.find("name").text : [ph.text for ph in adr.find_all("phone")] } for adr in xml.find_all("address")]
# Out:
# [{'Aicha Barki': ['+ (213) 6150 4015', '+ (213) 2173 5247']},
#  {'Francisco Domingos': ['+ (244-2) 325 023', '+ (244-2) 325 023']},
#  {'Maria Luisa': ['+ (244) 4232 2836']},
#  {'Abraao Chanda': ['+ (244-2) 325 023', '+ (244-2) 325 023']},
#  {'Beatriz Busaniche': ['+ (54-11) 4784 1159']},
#  {'Francesca Beddie': ['+ (61-2) 6274 9500', '+ (61-2) 6274 9513']},
#  {'Graham John Smith': ['+ (61-3) 9807 4702']}]

# %% [markdown]
# ## Лабораторная работа №4

# %% [markdown]
# ### JSON

# %% [markdown]
# 1.1 Считайте файл `contributors_sample.json`. Воспользовавшись модулем `json`, преобразуйте содержимое файла в соответствующие объекты python. Выведите на экран информацию о первых 3 пользователях.

# %%
with open("data/contributors_sample.json", 'r', encoding='utf8') as f:
    data = json.load(f)

data[:3]
# Out:
# [{'username': 'uhebert',
#   'name': 'Lindsey Nguyen',
#   'sex': 'F',
#   'address': '01261 Cameron Spring\nTaylorfurt, AK 97791',
#   'mail': 'jsalazar@gmail.com',
#   'jobs': ['Energy engineer',
#    'Engineer, site',
#    'Environmental health practitioner',
#    'Biomedical scientist',
#    'Jewellery designer'],
#   'id': 35193},
#  {'username': 'vickitaylor',
#   'name': 'Cheryl Lewis',
#   'sex': 'F',
#   'address': '66992 Welch Brooks\nMarshallshire, ID 56004',
#   'mail': 'bhudson@gmail.com',
#   'jobs': ['Music therapist',
#    'Volunteer coordinator',
#    'Designer, interior/spatial'],
#   'id': 91970},
#  {'username': 'sheilaadams',
#   'name': 'Julia Allen',
#   'sex': 'F',
#   'address': 'Unit 1632 Box 2971\nDPO AE 23297',
#   'mail': 'darren44@yahoo.com',
#   'jobs': ['Management consultant',
#    'Engineer, structural',
#    'Lecturer, higher education',
#    'Theatre manager',
#    'Designer, textile'],
#   'id': 1848091}]

# %% [markdown]
# 1.2 Выведите уникальные почтовые домены, содержащиеся в почтовых адресах людей

# %%
unique = set( [acc['mail'].split('@')[1] for acc in data] )
unique
# Out:
# {'gmail.com', 'hotmail.com', 'yahoo.com'}

# %% [markdown]
# 1.3 Напишите функцию, которая по `username` ищет человека и выводит информацию о нем. Если пользователь с заданным `username` отсутствует, возбудите исключение `ValueError`

# %%
def getUser(username):
    search = next((acc for acc in data if acc['username'] == username), None)
    if search: return search
    else: raise ValueError
            
getUser("vickitaylor")
# Out:
# {'username': 'vickitaylor',
#  'name': 'Cheryl Lewis',
#  'sex': 'F',
#  'address': '66992 Welch Brooks\nMarshallshire, ID 56004',
#  'mail': 'bhudson@gmail.com',
#  'jobs': ['Music therapist',
#   'Volunteer coordinator',
#   'Designer, interior/spatial'],
#  'id': 91970}

# %% [markdown]
# 1.4 Посчитайте, сколько мужчин и женщин присутсвует в этом наборе данных.

# %%
sexes = [acc['sex'] for acc in data]
{'F': sexes.count('F'), 'M':sexes.count('M')}
# Out:
# {'F': 2136, 'M': 2064}

# %% [markdown]
# 1.5 Создайте `pd.DataFrame` `contributors`, имеющий столбцы `id`, `username` и `sex`.

# %%
import pandas as pd
contributors = pd.DataFrame(data, columns=['id', 'username', 'sex'])
contributors
# Out:
#            id       username sex
# 0       35193        uhebert   F
# 1       91970    vickitaylor   F
# 2     1848091    sheilaadams   F
# 3       50969       nicole82   F
# 4      676820         jean67   M
# ...       ...            ...  ..
# 4195   423555  stevenspencer   F
# 4196    35251      rwilliams   M
# 4197   135887      lmartinez   F
# 4198   212714     brendahill   M
# 4199   344321       mistyray   F
#
# [4200 rows x 3 columns]

# %% [markdown]
# 1.6 Загрузите данные из файла `recipes_sample.csv` (__ЛР2__) в таблицу `recipes`. Объедините `recipes` с таблицей `contributors` с сохранением строк в том случае, если информация о человеке отсутствует в JSON-файле. Для скольких человек информация отсутствует?

# %%
recipes = pd.read_csv("data/recipes_sample.csv")
recipes = recipes.merge(contributors, how="left", left_on="contributor_id", right_on='id')
print(recipes['id_y'].isna().sum())
recipes
# Out:
# 15059
#                                                name    id_x  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# 2                1533  2002-08-29      NaN
# 3               22724  2002-07-27      NaN
# 4                4470  2004-02-23      4.0
# ...               ...         ...      ...
# 29995          200862  2007-11-25     16.0
# 29996          177443  2009-08-24      NaN
# 29997          161745  2004-11-03      NaN
# 29998          227978  2012-08-29      NaN
# 29999          506822  2008-04-15      9.0
#
#                                              description  n_ingredients  \
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29998  this is a delicious soup that i originally fou...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
#            id_y     username  sex
# 0       35193.0      uhebert    F
# 1       91970.0  vickitaylor    F
# 2           NaN          NaN  NaN
# 3           NaN          NaN  NaN
# 4           NaN          NaN  NaN
# ...         ...          ...  ...
# 29995  200862.0        ana38    F
# 29996  177443.0    douglas33    F
# 29997       NaN          NaN  NaN
# 29998  227978.0    jessica22    M
# 29999  506822.0    markchang    F
#
# [30000 rows x 11 columns]

# %% [markdown]
# ### pickle

# %% [markdown]
# 2.1 На основе файла `contributors_sample.json` создайте словарь следующего вида:
# ```
# {
#     должность: [список username людей, занимавших эту должность]
# }
# ```

# %%
data
# [acc['username'] for acc in data]
jobs = {}
jobs = {job: jobs.get(job, []).append(acc['username']) for acc in data for job in acc['jobs']}
jobs
# Out:
# {'Energy engineer': None,
#  'Engineer, site': None,
#  'Environmental health practitioner': None,
#  'Biomedical scientist': None,
#  'Jewellery designer': None,
#  'Music therapist': None,
#  'Volunteer coordinator': None,
#  'Designer, interior/spatial': None,
#  'Management consultant': None,
#  'Engineer, structural': None,
#  'Lecturer, higher education': None,
#  'Theatre manager': None,
#  'Designer, textile': None,
#  'Mechanical engineer': None,
#  'Retail banker': None,
#  'Barrister': None,
#  'Network engineer': None,
#  'Youth worker': None,
#  'Primary school teacher': None,
#  'Engineer, broadcasting (operations)': None,
#  'Designer, ceramics/pottery': None,
#  'Engineer, energy': None,
#  'Engineer, manufacturing': None,
#  'Designer, furniture': None,
#  'Sport and exercise psychologist': None,
#  'Hospital pharmacist': None,
#  'Surveyor, minerals': None,
#  'Geochemist': None,
#  'Restaurant manager': None,
#  'Clinical psychologist': None,
#  'Sports development officer': None,
#  'Firefighter': None,
#  'Charity fundraiser': None,
#  'Insurance underwriter': None,
#  'Analytical chemist': None,
#  'Holiday representative': None,
#  'Scientist, research (physical sciences)': None,
#  'Financial planner': None,
#  'Psychiatric nurse': None,
#  'Audiological scientist': None,
#  'Programmer, applications': None,
#  'Phytotherapist': None,
#  'Records manager': None,
#  'Secondary school teacher': None,
#  'Futures trader': None,
#  'Programmer, multimedia': None,
#  'Public affairs consultant': None,
#  'Therapeutic radiographer': None,
#  'IT trainer': None,
#  'Location manager': None,
#  'Production engineer': None,
#  'Chief Operating Officer': None,
#  'Hospital doctor': None,
#  'Radiation protection practitioner': None,
#  'Printmaker': None,
#  'Publishing copy': None,
#  'Research scientist (life sciences)': None,
#  'Chief Technology Officer': None,
#  'Call centre manager': None,
#  'Chief Executive Officer': None,
#  'Purchasing manager': None,
#  'Engineer, petroleum': None,
#  'Social researcher': None,
#  'Publishing rights manager': None,
#  'Tax adviser': None,
#  'Customer service manager': None,
#  'Forensic psychologist': None,
#  'Financial adviser': None,
#  'Photographer': None,
#  'Health and safety adviser': None,
#  'Product/process development scientist': None,
#  'Ceramics designer': None,
#  'Secretary/administrator': None,
#  'Patent attorney': None,
#  'Hotel manager': None,
#  'Quantity surveyor': None,
#  'Forest/woodland manager': None,
#  'Administrator, education': None,
#  'Nurse, adult': None,
#  'Multimedia programmer': None,
#  'Civil Service fast streamer': None,
#  'Psychologist, prison and probation services': None,
#  'Armed forces training and education officer': None,
#  'Glass blower/designer': None,
#  'Pharmacist, hospital': None,
#  'Warehouse manager': None,
#  'Psychologist, counselling': None,
#  'Pensions consultant': None,
#  'Trade mark attorney': None,
#  'Psychotherapist, child': None,
#  'Bonds trader': None,
#  'Journalist, broadcasting': None,
#  'Advice worker': None,
#  'Geologist, wellsite': None,
#  'Toxicologist': None,
#  'Media buyer': None,
#  'Engineer, civil (consulting)': None,
#  'Corporate treasurer': None,
#  'Nature conservation officer': None,
#  'Neurosurgeon': None,
#  'Special effects artist': None,
#  'Professor Emeritus': None,
#  'Rural practice surveyor': None,
#  'Education administrator': None,
#  'Arboriculturist': None,
#  'Facilities manager': None,
#  'Water engineer': None,
#  'Cabin crew': None,
#  'Radiographer, diagnostic': None,
#  'Chemist, analytical': None,
#  'Osteopath': None,
#  'Insurance claims handler': None,
#  'Quality manager': None,
#  'Designer, exhibition/display': None,
#  'Sub': None,
#  'Market researcher': None,
#  'Colour technologist': None,
#  'Emergency planning/management officer': None,
#  'Lexicographer': None,
#  'Water quality scientist': None,
#  'Engineer, water': None,
#  'Surveyor, insurance': None,
#  'Environmental manager': None,
#  'Maintenance engineer': None,
#  "Nurse, children's": None,
#  'Astronomer': None,
#  'Archaeologist': None,
#  'Journalist, newspaper': None,
#  'Accountant, chartered': None,
#  'Computer games developer': None,
#  'Drilling engineer': None,
#  'Librarian, academic': None,
#  'Biomedical engineer': None,
#  'Haematologist': None,
#  'Presenter, broadcasting': None,
#  'Surveyor, commercial/residential': None,
#  'Engineer, electronics': None,
#  'Surveyor, land/geomatics': None,
#  'Accountant, chartered management': None,
#  'Broadcast engineer': None,
#  'Engineer, building services': None,
#  'Patent examiner': None,
#  'Media planner': None,
#  'Ecologist': None,
#  'Geographical information systems officer': None,
#  'Paramedic': None,
#  'Designer, television/film set': None,
#  'Public librarian': None,
#  'Petroleum engineer': None,
#  'Sales professional, IT': None,
#  'Clinical molecular geneticist': None,
#  'Commercial art gallery manager': None,
#  'Television/film/video producer': None,
#  'Dispensing optician': None,
#  'Buyer, industrial': None,
#  'Energy manager': None,
#  'Structural engineer': None,
#  'Chief Strategy Officer': None,
#  'Building control surveyor': None,
#  'Product designer': None,
#  'Surveyor, planning and development': None,
#  'Architect': None,
#  'Dietitian': None,
#  'Engineer, chemical': None,
#  'Transport planner': None,
#  'Therapist, sports': None,
#  'Scientist, audiological': None,
#  'Learning mentor': None,
#  'Air broker': None,
#  'Oceanographer': None,
#  'Psychotherapist, dance movement': None,
#  'Physicist, medical': None,
#  'Equities trader': None,
#  'Dance movement psychotherapist': None,
#  'Electrical engineer': None,
#  'Site engineer': None,
#  'Occupational psychologist': None,
#  'Merchandiser, retail': None,
#  'Planning and development surveyor': None,
#  'Environmental education officer': None,
#  'Arts development officer': None,
#  'Horticultural therapist': None,
#  'Recruitment consultant': None,
#  'Editor, magazine features': None,
#  'Scientist, forensic': None,
#  'Geologist, engineering': None,
#  'IT sales professional': None,
#  'Psychologist, educational': None,
#  'Risk analyst': None,
#  'Scientist, research (life sciences)': None,
#  'Technical sales engineer': None,
#  'Adult nurse': None,
#  'Animal nutritionist': None,
#  'English as a foreign language teacher': None,
#  'Manufacturing systems engineer': None,
#  'Orthoptist': None,
#  'Financial trader': None,
#  'Clinical cytogeneticist': None,
#  'Nurse, learning disability': None,
#  'Chief of Staff': None,
#  'Child psychotherapist': None,
#  'Seismic interpreter': None,
#  'Retail manager': None,
#  'Logistics and distribution manager': None,
#  'Merchant navy officer': None,
#  'Microbiologist': None,
#  'Librarian, public': None,
#  'Education officer, community': None,
#  'Fitness centre manager': None,
#  'Gaffer': None,
#  'Theatre director': None,
#  'Aeronautical engineer': None,
#  'Research officer, government': None,
#  'Television camera operator': None,
#  'Administrator': None,
#  'Dealer': None,
#  'Surveyor, building': None,
#  'Broadcast presenter': None,
#  'Nurse, mental health': None,
#  'Curator': None,
#  'Aid worker': None,
#  'Press sub': None,
#  'Conservation officer, historic buildings': None,
#  'Insurance account manager': None,
#  'Public relations officer': None,
#  'Teaching laboratory technician': None,
#  'Air traffic controller': None,
#  'Occupational hygienist': None,
#  'Surgeon': None,
#  'Civil engineer, consulting': None,
#  'Insurance broker': None,
#  'Magazine journalist': None,
#  'Chartered accountant': None,
#  'Counsellor': None,
#  'Newspaper journalist': None,
#  'Surveyor, rural practice': None,
#  'Occupational therapist': None,
#  'Educational psychologist': None,
#  'Retail buyer': None,
#  'Mining engineer': None,
#  'Investment banker, corporate': None,
#  'Journalist, magazine': None,
#  'Graphic designer': None,
#  'Medical sales representative': None,
#  'Sports administrator': None,
#  'Stage manager': None,
#  'Broadcast journalist': None,
#  'Development worker, community': None,
#  'Surveyor, hydrographic': None,
#  'Estate agent': None,
#  'Scientist, physiological': None,
#  'Event organiser': None,
#  'Housing manager/officer': None,
#  'Lawyer': None,
#  'Systems developer': None,
#  'Engineer, aeronautical': None,
#  'Exhibition designer': None,
#  'Brewing technologist': None,
#  'Television production assistant': None,
#  'Embryologist, clinical': None,
#  'Trading standards officer': None,
#  'Actuary': None,
#  'Restaurant manager, fast food': None,
#  'International aid/development worker': None,
#  "Politician's assistant": None,
#  'Environmental consultant': None,
#  'Sports therapist': None,
#  'Biochemist, clinical': None,
#  'Sports coach': None,
#  'Airline pilot': None,
#  'Health and safety inspector': None,
#  'Cytogeneticist': None,
#  'Furniture designer': None,
#  'Paediatric nurse': None,
#  'Tax inspector': None,
#  'Bookseller': None,
#  'Set designer': None,
#  'Meteorologist': None,
#  'Community development worker': None,
#  'Control and instrumentation engineer': None,
#  'Producer, television/film/video': None,
#  'Charity officer': None,
#  'Historic buildings inspector/conservation officer': None,
#  'Lighting technician, broadcasting/film/video': None,
#  'Careers adviser': None,
#  'Product manager': None,
#  'Designer, multimedia': None,
#  'Licensed conveyancer': None,
#  'Archivist': None,
#  'Ship broker': None,
#  'Copywriter, advertising': None,
#  'Hydrogeologist': None,
#  'Hydrographic surveyor': None,
#  'Financial controller': None,
#  'Fashion designer': None,
#  'Cartographer': None,
#  'Scientist, water quality': None,
#  'Furniture conservator/restorer': None,
#  'Public relations account executive': None,
#  'Research officer, trade union': None,
#  'Museum/gallery curator': None,
#  'Print production planner': None,
#  'Musician': None,
#  'Education officer, museum': None,
#  'Games developer': None,
#  'Counselling psychologist': None,
#  'Museum/gallery conservator': None,
#  'Marketing executive': None,
#  'Production designer, theatre/television/film': None,
#  'Translator': None,
#  'Chief Financial Officer': None,
#  'Claims inspector/assessor': None,
#  'Radio broadcast assistant': None,
#  'Insurance risk surveyor': None,
#  'Government social research officer': None,
#  'Special educational needs teacher': None,
#  'Horticultural consultant': None,
#  'Administrator, arts': None,
#  'Legal secretary': None,
#  'Legal executive': None,
#  'Therapist, drama': None,
#  'Investment banker, operational': None,
#  'Advertising account planner': None,
#  'Higher education careers adviser': None,
#  'Scientist, product/process development': None,
#  'Diagnostic radiographer': None,
#  'Scientific laboratory technician': None,
#  'Teacher, special educational needs': None,
#  'Proofreader': None,
#  'Clinical scientist, histocompatibility and immunogenetics': None,
#  'Psychotherapist': None,
#  'Animal technologist': None,
#  'Company secretary': None,
#  'Senior tax professional/tax inspector': None,
#  'Producer, radio': None,
#  'Retail merchandiser': None,
#  'Learning disability nurse': None,
#  'Designer, graphic': None,
#  'Tourism officer': None,
#  "Barrister's clerk": None,
#  'Research officer, political party': None,
#  'Heritage manager': None,
#  'Consulting civil engineer': None,
#  'Conservator, furniture': None,
#  'Software engineer': None,
#  'Outdoor activities/education manager': None,
#  'Clothing/textile technologist': None,
#  'Industrial buyer': None,
#  'Health physicist': None,
#  'Operations geologist': None,
#  'Scientist, research (medical)': None,
#  'Conservator, museum/gallery': None,
#  'Health service manager': None,
#  'Garment/textile technologist': None,
#  'Engineer, biomedical': None,
#  'Agricultural engineer': None,
#  'Soil scientist': None,
#  'Secretary, company': None,
#  'Wellsite geologist': None,
#  'Conference centre manager': None,
#  'Nutritional therapist': None,
#  'Fast food restaurant manager': None,
#  'Equality and diversity officer': None,
#  'Public house manager': None,
#  'Scientist, marine': None,
#  'Therapist, horticultural': None,
#  'Commissioning editor': None,
#  'Clinical research associate': None,
#  'Immunologist': None,
#  'Personnel officer': None,
#  'Chiropractor': None,
#  'Information systems manager': None,
#  'Artist': None,
#  'Medical secretary': None,
#  'Administrator, charities/voluntary organisations': None,
#  'Armed forces operational officer': None,
#  'Best boy': None,
#  'Ophthalmologist': None,
#  'Administrator, sports': None,
#  'Pathologist': None,
#  'Engineering geologist': None,
#  'Tour manager': None,
#  'Air cabin crew': None,
#  'Further education lecturer': None,
#  'Minerals surveyor': None,
#  'Buyer, retail': None,
#  'Information officer': None,
#  'Physiological scientist': None,
#  'Video editor': None,
#  'Chief Marketing Officer': None,
#  'Human resources officer': None,
#  'Theatre stage manager': None,
#  'Mudlogger': None,
#  'Editor, film/video': None,
#  'Statistician': None,
#  'Chartered management accountant': None,
#  'Engineer, maintenance': None,
#  'Office manager': None,
#  'Electronics engineer': None,
#  'Engineer, technical sales': None,
#  'Tree surgeon': None,
#  'Database administrator': None,
#  'Academic librarian': None,
#  'Pension scheme manager': None,
#  'Geneticist, molecular': None,
#  'Communications engineer': None,
#  'Conservation officer, nature': None,
#  'Barista': None,
#  'Travel agency manager': None,
#  'Lecturer, further education': None,
#  'Commercial/residential surveyor': None,
#  'Mental health nurse': None,
#  'Financial risk analyst': None,
#  'Radiographer, therapeutic': None,
#  'Accountant, chartered public finance': None,
#  'Dentist': None,
#  'Estate manager/land agent': None,
#  'Research scientist (maths)': None,
#  'Corporate investment banker': None,
#  'Interpreter': None,
#  'Building services engineer': None,
#  'Training and development officer': None,
#  'Teacher, early years/pre': None,
#  'Therapist, speech and language': None,
#  'Television floor manager': None,
#  'Teacher, secondary school': None,
#  'Optician, dispensing': None,
#  'Radio producer': None,
#  'Operational researcher': None,
#  'Materials engineer': None,
#  'Comptroller': None,
#  'Private music teacher': None,
#  'Town planner': None,
#  'Clinical embryologist': None,
#  'Chartered public finance accountant': None,
#  'Contracting civil engineer': None,
#  'Advertising art director': None,
#  'Teacher, English as a foreign language': None,
#  'Psychologist, sport and exercise': None,
#  'Doctor, hospital': None,
#  'Contractor': None,
#  'Farm manager': None,
#  'Interior and spatial designer': None,
#  'Health visitor': None,
#  'Technical author': None,
#  'Recycling officer': None,
#  'Optometrist': None,
#  'Geoscientist': None,
#  'Fine artist': None,
#  'Press photographer': None,
#  'Police officer': None,
#  'Editor, commissioning': None,
#  'Sound technician, broadcasting/film/video': None,
#  'Catering manager': None,
#  'Hydrologist': None,
#  'Banker': None,
#  'Chiropodist': None,
#  'Homeopath': None,
#  'Copy': None,
#  'Land/geomatics surveyor': None,
#  'Designer, industrial/product': None,
#  'Magazine features editor': None,
#  'Building surveyor': None,
#  'Medical technical officer': None,
#  'Engineer, maintenance (IT)': None,
#  'Social worker': None,
#  'Engineer, control and instrumentation': None,
#  'Midwife': None,
#  'Chemical engineer': None,
#  'Administrator, local government': None,
#  'Adult guidance worker': None,
#  'Podiatrist': None,
#  'Waste management officer': None,
#  'Architectural technologist': None,
#  'Civil engineer, contracting': None,
#  'Animator': None,
#  'Local government officer': None,
#  'Horticulturist, amenity': None,
#  'Accommodation manager': None,
#  'Financial manager': None,
#  'Telecommunications researcher': None,
#  'Theme park manager': None,
#  'Diplomatic Services operational officer': None,
#  'Textile designer': None,
#  'Medical illustrator': None,
#  'Exercise physiologist': None,
#  'Automotive engineer': None,
#  'Sales executive': None,
#  'Physiotherapist': None,
#  'Engineer, land': None,
#  'Geophysicist/field seismologist': None,
#  'Camera operator': None,
#  'Solicitor, Scotland': None,
#  'TEFL teacher': None,
#  'Acupuncturist': None,
#  'Art therapist': None,
#  'Surveyor, quantity': None,
#  'Advertising copywriter': None,
#  'Designer, jewellery': None,
#  'Armed forces logistics/support/administrative officer': None,
#  'Amenity horticulturist': None,
#  'Risk manager': None,
#  'Oncologist': None,
#  'Clinical biochemist': None,
#  'Probation officer': None,
#  'Multimedia specialist': None,
#  'Surveyor, mining': None,
#  'Fisheries officer': None,
#  'Social research officer, government': None,
#  'Careers information officer': None,
#  'Psychologist, clinical': None,
#  'Film/video editor': None,
#  'Scientist, research (maths)': None,
#  'Chartered certified accountant': None,
#  'Museum/gallery exhibitions officer': None,
#  'Designer, blown glass/stained glass': None,
#  'Data processing manager': None,
#  'Education officer, environmental': None,
#  'Investment analyst': None,
#  'Higher education lecturer': None,
#  'Illustrator': None,
#  'Development worker, international aid': None,
#  'Engineer, mining': None,
#  'Regulatory affairs officer': None,
#  'Art gallery manager': None,
#  'Tourist information centre manager': None,
#  'Landscape architect': None,
#  'Programme researcher, broadcasting/film/video': None,
#  'Land': None,
#  'Metallurgist': None,
#  'Visual merchandiser': None,
#  'IT technical support officer': None,
#  'Early years teacher': None,
#  'Teacher, music': None,
#  'Programmer, systems': None,
#  'Loss adjuster, chartered': None,
#  'Engineer, drilling': None,
#  'Marine scientist': None,
#  'Associate Professor': None,
#  'Operational investment banker': None,
#  'Exhibitions officer, museum/gallery': None,
#  'Applications developer': None,
#  'Intelligence analyst': None,
#  'Civil Service administrator': None,
#  'Pharmacologist': None,
#  'Health promotion specialist': None,
#  'Personal assistant': None,
#  'Field trials officer': None,
#  'Advertising account executive': None,
#  'General practice doctor': None,
#  'Writer': None,
#  'Doctor, general practice': None,
#  'Warden/ranger': None,
#  'Speech and language therapist': None,
#  'Data scientist': None,
#  'Commercial horticulturist': None,
#  'Naval architect': None,
#  'Technical brewer': None,
#  'Engineer, materials': None,
#  'Herpetologist': None,
#  'Research scientist (medical)': None,
#  'Pilot, airline': None,
#  'Veterinary surgeon': None,
#  'Museum education officer': None,
#  'Production assistant, television': None,
#  'Therapist, art': None,
#  'Editorial assistant': None,
#  'Horticulturist, commercial': None,
#  'Engineer, automotive': None,
#  'Food technologist': None,
#  'Agricultural consultant': None,
#  'Immigration officer': None,
#  'Accountant, chartered certified': None,
#  'Engineer, communications': None,
#  'Surveyor, building control': None,
#  'Herbalist': None,
#  'Systems analyst': None,
#  'Therapist, music': None,
#  'Production manager': None,
#  'Designer, fashion/clothing': None,
#  'Chartered loss adjuster': None,
#  'Engineer, agricultural': None,
#  'Race relations officer': None,
#  'Engineer, manufacturing systems': None,
#  'Lobbyist': None,
#  'Community arts worker': None,
#  'Medical physicist': None,
#  'Leisure centre manager': None,
#  'Dancer': None,
#  'Teacher, adult education': None,
#  'Community education officer': None,
#  'Accounting technician': None,
#  'IT consultant': None,
#  'Scientist, biomedical': None,
#  'Plant breeder/geneticist': None,
#  'Geophysical data processor': None,
#  'Armed forces technical officer': None,
#  'Teacher, primary school': None,
#  'Freight forwarder': None,
#  'Psychiatrist': None,
#  'Economist': None,
#  'Quarry manager': None,
#  'Therapist, nutritional': None,
#  'Production assistant, radio': None,
#  'Web designer': None,
#  'Ambulance person': None,
#  'Chartered legal executive (England and Wales)': None,
#  'Field seismologist': None,
#  'Scientist, clinical (histocompatibility and immunogenetics)': None,
#  'Prison officer': None,
#  'Engineer, electrical': None,
#  'Forensic scientist': None,
#  'English as a second language teacher': None,
#  'Psychologist, occupational': None,
#  'Arts administrator': None,
#  'Ergonomist': None,
#  'Passenger transport manager': None,
#  'Psychologist, forensic': None,
#  'Sales promotion account executive': None,
#  'Make': None,
#  'Science writer': None,
#  'Administrator, Civil Service': None,
#  'Industrial/product designer': None,
#  'Community pharmacist': None,
#  'Dramatherapist': None,
#  'Pharmacist, community': None,
#  'Engineer, civil (contracting)': None,
#  'Trade union research officer': None,
#  'Fish farm manager': None,
#  'Research scientist (physical sciences)': None,
#  'Solicitor': None,
#  'Actor': None,
#  'Music tutor': None,
#  'Engineer, production': None,
#  'Runner, broadcasting/film/video': None,
#  'Medical laboratory scientific officer': None,
#  'Manufacturing engineer': None,
#  'Therapist, occupational': None,
#  'Ranger/warden': None}

# %% [markdown]
# 2.2 Сохраните результаты в файл `job_people.pickle` и в файл `job_people.json` с использованием форматов pickle и JSON соответственно. Сравните объемы получившихся файлов. При сохранении в JSON укажите аргумент `indent`.

# %%
with open("./data/job_people.pickle", "wb") as f:
    pickle.dump(jobLitUsers, f)

with open("./data/job_people.json", "w") as f:
    json.dump(jobLitUsers, f, indent=1)

##Файл JSON больше
# Out:
# Running cells with 'c:\msys64\mingw64\bin\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/msys64/mingw64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# 2.3 Считайте файл `job_people.pickle` и продемонстрируйте, что данные считались корректно.

# %%
with open("./data/job_people.pickle", "rb") as f:
    job_people = pickle.load(f)
pp(job_people)
# Out:
# Running cells with 'c:\msys64\mingw64\bin\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/msys64/mingw64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### XML

# %% [markdown]
# 3.1 По данным файла `steps_sample.xml` сформируйте словарь с шагами по каждому рецепту вида `{id_рецепта: ["шаг1", "шаг2"]}`. Сохраните этот словарь в файл `steps_sample.json`

# %%
with open("./data/steps_sample.xml", "r", encoding="UTF-8") as f:
    steps_sample = BeautifulSoup(f, "xml")
# Out:
# Running cells with 'c:\msys64\mingw64\bin\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/msys64/mingw64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
dict_xml = {}
for recipe in steps_sample.recipes.find_all("recipe"):
    if recipe.id.text not in dict_xml:
        dict_xml[recipe.id.text] = [] #recipe.find_all("steps")
    for steps in recipe.find_all("step"):
        dict_xml[recipe.id.text].append(steps.text)
dict_xml
# Out:
# Running cells with 'c:\msys64\mingw64\bin\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/msys64/mingw64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
with open("./data/steps_sample.json", "w") as f:
    json.dump(dict_xml, f, indent=1)
# Out:
# Running cells with 'c:\msys64\mingw64\bin\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/msys64/mingw64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# 3.2 По данным файла `steps_sample.xml` сформируйте словарь следующего вида: `кол-во_шагов_в_рецепте: [список_id_рецептов]`

# %%
count_steps_recipes = {}
for recipes in steps_sample.recipes.find_all("recipe"):
    if len(recipes.steps) not in count_steps_recipes:
        count_steps_recipes[len(recipes.steps)] = []
    count_steps_recipes[len(recipes.steps)].append(recipes.find("id").text)

pp(count_steps_recipes)
# Out:
# Running cells with 'c:\msys64\mingw64\bin\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/msys64/mingw64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# 3.3 Получите список рецептов, в этапах выполнения которых есть информация о времени (часы или минуты). Для отбора подходящих рецептов обратите внимание на атрибуты соответствующих тэгов.

# %%
time_recipes = []
for recipe in steps_sample.recipes.find_all("recipe"):
    if recipe.find("step", attrs={'has_minutes': '1'}) or recipe.find("step", attrs={'has_hours': "1"}):
        time_recipes.append(recipe.id.text)
time_recipes
# Out:
# Running cells with 'c:\msys64\mingw64\bin\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/msys64/mingw64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# 3.4 Загрузите данные из файла `recipes_sample.csv` (__ЛР2__) в таблицу `recipes`. Для строк, которые содержат пропуски в столбце `n_steps`, заполните этот столбец на основе файла  `steps_sample.xml`. Строки, в которых столбец `n_steps` заполнен, оставьте без изменений.

# %%
recipes_sample = pd.read_csv("../../ЛР2/02_pandas/data/recipes_sample.csv", sep=",")
recipes_sample[:100]
# Out:
# Running cells with 'c:\msys64\mingw64\bin\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/msys64/mingw64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
for recipe in steps_sample.recipes.find_all("recipe"):
    recipe_id = int(recipe.id.text)
    if np.isnan(recipes_sample[recipes_sample["id"] == recipe_id]["n_steps"].iloc[0]):
        recipes_sample.loc[recipes_sample.id == recipe_id, "n_steps"] = len(recipe.find_all("step"))

recipes_sample[:100]
# Out:
# Running cells with 'c:\msys64\mingw64\bin\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/msys64/mingw64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# 3.5 Проверьте, содержит ли столбец `n_steps` пропуски. Если нет, то преобразуйте его к целочисленному типу и сохраните результаты в файл `recipes_sample_with_filled_nsteps.csv`

# %%
pp(np.sum(np.isnan(recipes_sample["n_steps"])))
recipes_sample["n_steps"] = recipes_sample["n_steps"].astype("Int64")
recipes_sample.head()
# Out:
# Running cells with 'c:\msys64\mingw64\bin\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/msys64/mingw64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
recipes_sample.to_csv("./data/recipes_sample_with_filled_nsteps.csv")
# Out:
# Running cells with 'c:\msys64\mingw64\bin\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/msys64/mingw64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'
